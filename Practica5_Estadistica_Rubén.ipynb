# %% [markdown]
# <a href="https://colab.research.google.com/github/Rpin97/Curso-Python/blob/main/Practica5_FINAL_Ruben.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DCDPUAEM/DCDP/blob/main/02%20An%C3%A1lisis%20Estad%C3%ADstico/notebooks/exercises/Practica5_Estadistica.ipynb)

# %% [markdown]
# ----
#
# <h1><center>Monte Carlo</center></h1>
#
#
# El algoritmo se basa en el muestreo aleatorio repetido en un intento de determinar la probabilidad. Esto significa simular un evento con entradas aleatorias un gran número de veces para obtener su estimación.
#
# Las simulaciones Monte Carlo se pueden utilizar en una amplia gama de campos que van desde la economía, el juego, la ingeniería, la energía y cualquier otro campo intermedio. Por lo tanto, no importa en qué campo profesional se encuentre, es algo excelente que debe conocer.
#
# ---
#
# Al aprender a construir simulaciones Monte Carlo, es mejor comenzar con un modelo básico para comprender los fundamentos. La forma más fácil y común de hacerlo es con juegos simples, por lo que utilizaremos un juego de dados en este caso.
#
# Probablemente haya escuchado el dicho, "la casa siempre gana", así que para este ejemplo, la casa (típicamente un casino) tendrá una ventaja, y mostraremos lo que eso significa para las posibles ganancias del jugador.

# %% [markdown]
# ## El juego de dados
#
# Nuestro juego simple involucrará dos dados de seis caras. P
#
# ara ganar, el jugador debe sacar el mismo número en ambos dados.
#
# Un dado de seis caras tiene seis resultados posibles (1, 2, 3, 4, 5 y 6). Con dos dados, ahora hay 36 resultados posibles (1 y 1, 1 y 2, 1 y 3, etc., o 6 x 6 = 36 posibilidades).
#
# En este juego, la casa tiene más oportunidades de ganar (30 resultados frente a los 6 resultados del jugador), lo que significa que la casa tiene bastante ventaja.
#
# ---
#
# Digamos que nuestro jugador comienza con un saldo de 1,000 y está preparado para perderlo todo, por lo que apuesta 1 en cada tirada (lo que significa que se tiran ambos dados) y decide jugar 1,000 tiradas. Debido a que la casa es tan generosa, ofrecen pagar 4 veces la apuesta del jugador cuando el jugador gana.
#
# Por ejemplo, si el jugador gana la primera tirada, su saldo aumenta en $4 y finaliza la ronda con un saldo de 1,004. Si milagrosamente lograban una racha de 1000 victorias, podrían irse a casa con 5000. Si perdía todas las rondas, podrían irse a casa sin nada. No es una mala relación riesgo-recompensa… o tal vez lo sea.

# %%
# Importando paqueterias
import matplotlib.pyplot as plt
import random

# %% [markdown]
# Ahora, debemos definir nuestra función que genere valores entre 1 y 6 para ambos dados. Podemos auxiliarnos con la funcion *random.randinit()*
#
# Tomando en consideración la condición de que si el dado 1 es identico al dado 2, tendremos un resultado positivo en la apuesta, caso contrario, tendremos una derrota.

# %%
# Creando función de lanzamiento de dados
def roll_dice():
    # Generar un número aleatorio para el primer dado
    result_dice1 = random.randint(1, 6)
    # Generar un número aleatorio para el segundo dado
    result_dice2 = random.randint(1, 6)

    # Verificar si ambos dados tienen el mismo número
    same_number = result_dice1 == result_dice2

    return same_number

# %% [markdown]
# Cada simulación Monte Carlo requerirá que sepa cuáles son sus entradas y qué información está buscando obtener.
#
# En esta práctica, ya definimos cuáles son nuestras entradas cuando describimos el juego. **Dijimos que nuestra cantidad de tiradas por juego es 1,000, y la cantidad que el jugador apostará en cada tirada es $1**.
#
# Además de nuestras variables de entrada, necesitamos definir cuántas veces queremos simular el juego. Podemos usar la variable num_simulations como nuestro conteo de simulación de Monte Carlo. Cuanto más alto hagamos este número, más precisa será la probabilidad predicha de su valor real.
#
# La cantidad de variables que podemos rastrear generalmente aumenta con la complejidad de un proyecto, por lo que es importante precisar sobre qué información deseamos trabajar.
#
# Para este caso, realizaremos un seguimiento de la probabilidad de ganar (ganancias por juego divididas por el número total de tiradas) y el saldo final para cada simulación (o juego). Estos se inicializan como listas y se actualizarán al final de cada juego.

# %%
# Definir variables de entrada
num_simulations = 10000  # Número de simulaciones
max_num_rolls = 1000  # Máximo número de tiradas por juego
bet = 1  # Apuesta por tirada ($1)

# Definir variables de configuración de la figura
line_color = 'b'  # Color azul para la línea de saldo del jugador
scatter_color = 'r'  # Color rojo para los puntos de saldo final

# Inicializar listas de seguimiento
win_probability = []  # Lista para almacenar probabilidades de ganar por juego
end_balance = []  # Lista para almacenar saldos finales de cada juego

# Crear figura para los ejemplos de simulación
fig = plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.title('Simulación Monte Carlo: Probabilidad de ganar y saldo final')  # Título de la figura
plt.xlabel('Número de tiradas')  # Etiqueta del eje x
plt.ylabel('Valor')  # Etiqueta del eje y
plt.xlim(0, max_num_rolls)  # Límites del eje x

# For para ejecutar todas las simulaciones deseadas
for i in range(num_simulations):
    # Inicializar variables de seguimiento para el juego actual
    player_balance = [1000]  # Saldo inicial del jugador como lista para trazado
    num_rolls = [0]  # Lista para almacenar el número de tiradas por juego
    num_wins = 0  # Contador de victorias para el juego actual

    # Simulación de las tiradas del juego actual
    while num_rolls[-1] < max_num_rolls:
        # Realizar tirada de dados
        if roll_dice():  # Si los dados muestran el mismo número
            player_balance.append(player_balance[-1] + 4)  # Aumentar saldo en 4 dólares
            num_wins += 1  # Incrementar contador de victorias
        else:
            player_balance.append(player_balance[-1] - bet)  # Restar apuesta del saldo

        # Actualizar el número de tiradas
        num_rolls.append(num_rolls[-1] + 1)

    # Calcular probabilidad de ganar y almacenar saldo final del juego
    win_probability.append(num_wins / max_num_rolls)
    end_balance.append(player_balance[-1])

    # Agregar una línea a la figura para visualizar los resultados después de cada juego
    plt.plot(num_rolls, player_balance, color=line_color, alpha=0.1)  # Línea de saldo del jugador por juego

# Visualizar la gráfica
plt.show()

# %% [markdown]
# # **Aqui intentamos hacer de una vez la gràfica y saliò bien, pero no logramos que mostrara los puntos de saldo final en rojo, pero ya màs adelante nos quedó bien la gráfica**

# %% [markdown]
# ### Configuración de la figura
#
# El siguiente paso es configurar nuestra figura antes de ejecutar la simulación. Al hacer esto antes de la simulación, nos permite agregar líneas a nuestra figura después de cada juego. Luego, una vez que hayamos ejecutado todas las simulaciones, podemos mostrar la gráfica para mostrar nuestros resultados.

# %%
# Importar la biblioteca de visualización
import matplotlib.pyplot as plt

num_simulations = 10000  # Número de simulaciones

# Crear figura con etiquetas y titulo para los ejemplos de simulación
fig = plt.figure(figsize=(10, 6))
plt.title('Simulación Monte Carlo: Probabilidad de ganar y saldo final')
plt.xlabel('Simulación')
plt.ylabel('Valor')
plt.xlim(0, num_simulations)

# Visualización de la gráfica
plt.show()

# %% [markdown]
# En el siguiente código, tenemos un bucle for externo que itera a través de nuestro número predefinido de simulaciones (10 000 simulaciones) y un bucle while anidado que ejecuta cada juego (1000 tiradas).
#
# Antes de comenzar cada ciclo while, inicializamos el saldo del jugador como $1,000 (como una lista para fines de trazado) y un conteo de tiradas y ganancias.
#
#     * Nuestro bucle while simulará el juego durante 1000 tiradas. Dentro de este bucle, lanzamos los dados y usamos la variable booleana devuelta por roll_dice() para determinar el resultado. Si los dados son del mismo número, agregamos 4 veces la apuesta a la lista de saldo y agregamos una ganancia al conteo de ganancias. Si los dados son diferentes, restamos la apuesta de la lista de saldo. Al final de cada lanzamiento, agregamos un conteo a nuestra lista num_rolls.
#
# Una vez que el número de lanzamientos llega a 1000, podemos calcular la probabilidad de ganar del jugador como el número de ganancias dividido por el número total de lanzamientos.
#
# También podemos almacenar el saldo final del juego completo en la variable de seguimiento end_balance. Finalmente, podemos trazar las variables num_rolls y balance para agregar una línea a la figura que definimos anteriormente.

# %%
# For para ejecutar todas las simulaciones deseadas
for i in range(num_simulations):
    # Inicializar variables
    player_balance = [1000]  # Saldo inicial
    num_rolls = [0]  #  número de tiradas por juego
    num_wins = 0  # Contador de victorias

    # Simulación de las tiradas
    while num_rolls[-1] < max_num_rolls:
        if roll_dice():
            player_balance.append(player_balance[-1] + 4)
            num_wins += 1
        else:
            player_balance.append(player_balance[-1] - bet)

        # Actualizo tiradas
        num_rolls.append(num_rolls[-1] + 1)

    # Calcular probabilidad de ganar
    win_probability.append(num_wins / max_num_rolls)
    end_balance.append(player_balance[-1])

    # Añado una linea al plot
    plt.plot(num_rolls, player_balance)  # Línea de saldo del jugador por juego

# Visualizar la gráfica
plt.show()

# %%
# Probabilidad promedio de victoria
overall_win_probability = sum(win_probability) / len(win_probability)

# Saldo final promedio
overall_end_balance = sum(end_balance) / len(end_balance)

# Imprimir resultados
print("Promedio de victorias después de " + str(num_simulations) + " simulaciones: " + str(overall_win_probability))
print("Saldo promedio después de " + str(num_simulations) + " simulaciones: $" + str(overall_end_balance))
# Out:
# Promedio de victorias después de 10000 simulaciones: 0.16668179999999833
# Saldo promedio después de 10000 simulaciones: $833.409

# %% [markdown]
# ## Desafio complementario
#
# Ahora, realiza el mismo procedimiento pero mostrando los
# resultados para 10, 100, 1000 y 10000 lanzamientos, considerando 200, 2000 y 20000 simulaciones.
#
# Como bien sabemos, cada que gana el individuo, la casa le pagaba 4 veces el valor de la apuesta.
# Ahora, si gana, le pagaran 6 veces mas de lo apostado, siempre y cuando el individuo apueste de 3 en 3.
#
# El monto inicial sería ahora de 800. ¿Cuánta diferencia existe entre los resultados obtenidos para cada escenario?
# ¿En cuales se tiene un porcentaje mayor de victoria?
#
# Grafica estos resultados utilizando graficas de pastel y de barras y realiza una comparación entre ellos.

# %%
import matplotlib.pyplot as plt
import random

def roll_dice():
    result_dice1 = random.randint(1, 6)
    result_dice2 = random.randint(1, 6)
    same_number = result_dice1 == result_dice2
    return same_number

def simulate_game(num_rolls, bet, initial_balance):
    player_balance = [initial_balance]
    num_wins = 0

    for _ in range(num_rolls):
        if roll_dice():
            player_balance.append(player_balance[-1] + bet * 6)
            num_wins += 1
        else:
            player_balance.append(player_balance[-1] - bet)

    return num_wins / num_rolls, player_balance[-1]

def run_simulations(num_simulations, num_rolls, bet, initial_balance):
    win_probabilities = []
    end_balances = []

    for _ in range(num_simulations):
        win_rate, final_balance = simulate_game(num_rolls, bet, initial_balance)
        win_probabilities.append(win_rate)
        end_balances.append(final_balance)

    return win_probabilities, end_balances

#Cambio los parametros
bet = 3  # apuesta
initial_balance = 800  # balance inicial

# Hago simulaciones con distintos numeros de tiradas
simulation_results = []
for num_rolls_per_game in [10, 100, 1000, 10000]:
    for num_sims in [200, 2000, 20000]:
        win_probabilities, end_balances = run_simulations(num_sims, num_rolls_per_game, bet, initial_balance)

        average_win_rate = sum(win_probabilities) / len(win_probabilities)
        average_end_balance = sum(end_balances) / len(end_balances)

        simulation_results.append({
            "num_rolls_per_game": num_rolls_per_game,
            "num_sims": num_sims,
            "average_win_rate": average_win_rate,
            "average_end_balance": average_end_balance
        })

# Comparo los resultados
print("-" * 80)
print("Comparison of Simulation Results")
print("-" * 80)

# Calculo la diferencia de los porcentajes entre el promedio de victorias y de balances finales
for i, result1 in enumerate(simulation_results):
    for j, result2 in enumerate(simulation_results):
        if i != j:
            pct_diff_win_rate = ((result2["average_win_rate"] - result1["average_win_rate"]) / result1["average_win_rate"]) * 100
            pct_diff_end_balance = ((result2["average_end_balance"] - result1["average_end_balance"]) / result1["average_end_balance"]) * 100

            print(f"Comparing {result1['num_rolls_per_game']} rolls, {result1['num_sims']} sims to {result2['num_rolls_per_game']} rolls, {result2['num_sims']} sims:")
            print(f" - Win Rate: {result1['average_win_rate']:.4f} vs {result2['average_win_rate']:.4f} ({pct_diff_win_rate:.2f}%)")
            print(f" - End Balance: ${result1['average_end_balance']:.2f} vs ${result2['average_end_balance']:.2f} ({pct_diff_end_balance:.2f}%)")

# Calculo que escenarios tienen mayores victorias
highest_win_rates = sorted(simulation_results, key=lambda x: x["average_win_rate"], reverse=True)[:3]
print("\nScenarios with Highest Win Rates:")
for result in highest_win_rates:
    print(f" - {result['num_rolls_per_game']} rolls, {result['num_sims']} sims: {result['average_win_rate']:.4f}")

#Para graficar
win_rates_data = [result["average_win_rate"] for result in simulation_results]
# Out:
# --------------------------------------------------------------------------------
# Comparison of Simulation Results
# --------------------------------------------------------------------------------
# Comparing 10 rolls, 200 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1630 vs 0.1652 (1.35%)
#  - End Balance: $804.23 vs $804.69 (0.06%)
# Comparing 10 rolls, 200 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1630 vs 0.1688 (3.55%)
#  - End Balance: $804.23 vs $805.44 (0.15%)
# Comparing 10 rolls, 200 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1630 vs 0.1709 (4.85%)
#  - End Balance: $804.23 vs $858.89 (6.80%)
# Comparing 10 rolls, 200 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1630 vs 0.1661 (1.89%)
#  - End Balance: $804.23 vs $848.76 (5.54%)
# Comparing 10 rolls, 200 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1630 vs 0.1667 (2.30%)
#  - End Balance: $804.23 vs $850.16 (5.71%)
# Comparing 10 rolls, 200 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1630 vs 0.1656 (1.57%)
#  - End Balance: $804.23 vs $1276.87 (58.77%)
# Comparing 10 rolls, 200 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1630 vs 0.1667 (2.26%)
#  - End Balance: $804.23 vs $1300.35 (61.69%)
# Comparing 10 rolls, 200 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1630 vs 0.1665 (2.17%)
#  - End Balance: $804.23 vs $1297.36 (61.32%)
# Comparing 10 rolls, 200 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1630 vs 0.1668 (2.34%)
#  - End Balance: $804.23 vs $5831.57 (625.11%)
# Comparing 10 rolls, 200 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1630 vs 0.1667 (2.28%)
#  - End Balance: $804.23 vs $5810.75 (622.52%)
# Comparing 10 rolls, 200 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1630 vs 0.1666 (2.24%)
#  - End Balance: $804.23 vs $5796.20 (620.71%)
# Comparing 10 rolls, 2000 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1652 vs 0.1630 (-1.33%)
#  - End Balance: $804.69 vs $804.23 (-0.06%)
# Comparing 10 rolls, 2000 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1652 vs 0.1688 (2.17%)
#  - End Balance: $804.69 vs $805.44 (0.09%)
# Comparing 10 rolls, 2000 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1652 vs 0.1709 (3.45%)
#  - End Balance: $804.69 vs $858.89 (6.74%)
# Comparing 10 rolls, 2000 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1652 vs 0.1661 (0.53%)
#  - End Balance: $804.69 vs $848.76 (5.48%)
# Comparing 10 rolls, 2000 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1652 vs 0.1667 (0.93%)
#  - End Balance: $804.69 vs $850.16 (5.65%)
# Comparing 10 rolls, 2000 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1652 vs 0.1656 (0.22%)
#  - End Balance: $804.69 vs $1276.87 (58.68%)
# Comparing 10 rolls, 2000 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1652 vs 0.1667 (0.90%)
#  - End Balance: $804.69 vs $1300.35 (61.60%)
# Comparing 10 rolls, 2000 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1652 vs 0.1665 (0.81%)
#  - End Balance: $804.69 vs $1297.36 (61.22%)
# Comparing 10 rolls, 2000 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1652 vs 0.1668 (0.98%)
#  - End Balance: $804.69 vs $5831.57 (624.70%)
# Comparing 10 rolls, 2000 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1652 vs 0.1667 (0.92%)
#  - End Balance: $804.69 vs $5810.75 (622.11%)
# Comparing 10 rolls, 2000 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1652 vs 0.1666 (0.88%)
#  - End Balance: $804.69 vs $5796.20 (620.30%)
# Comparing 10 rolls, 20000 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1688 vs 0.1630 (-3.43%)
#  - End Balance: $805.44 vs $804.23 (-0.15%)
# Comparing 10 rolls, 20000 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1688 vs 0.1652 (-2.12%)
#  - End Balance: $805.44 vs $804.69 (-0.09%)
# Comparing 10 rolls, 20000 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1688 vs 0.1709 (1.25%)
#  - End Balance: $805.44 vs $858.89 (6.64%)
# Comparing 10 rolls, 20000 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1688 vs 0.1661 (-1.61%)
#  - End Balance: $805.44 vs $848.76 (5.38%)
# Comparing 10 rolls, 20000 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1688 vs 0.1667 (-1.21%)
#  - End Balance: $805.44 vs $850.16 (5.55%)
# Comparing 10 rolls, 20000 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1688 vs 0.1656 (-1.91%)
#  - End Balance: $805.44 vs $1276.87 (58.53%)
# Comparing 10 rolls, 20000 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1688 vs 0.1667 (-1.25%)
#  - End Balance: $805.44 vs $1300.35 (61.45%)
# Comparing 10 rolls, 20000 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1688 vs 0.1665 (-1.33%)
#  - End Balance: $805.44 vs $1297.36 (61.07%)
# Comparing 10 rolls, 20000 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1688 vs 0.1668 (-1.17%)
#  - End Balance: $805.44 vs $5831.57 (624.02%)
# Comparing 10 rolls, 20000 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1688 vs 0.1667 (-1.22%)
#  - End Balance: $805.44 vs $5810.75 (621.43%)
# Comparing 10 rolls, 20000 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1688 vs 0.1666 (-1.27%)
#  - End Balance: $805.44 vs $5796.20 (619.63%)
# Comparing 100 rolls, 200 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1709 vs 0.1630 (-4.62%)
#  - End Balance: $858.89 vs $804.23 (-6.36%)
# Comparing 100 rolls, 200 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1709 vs 0.1652 (-3.34%)
#  - End Balance: $858.89 vs $804.69 (-6.31%)
# Comparing 100 rolls, 200 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1709 vs 0.1688 (-1.24%)
#  - End Balance: $858.89 vs $805.44 (-6.22%)
# Comparing 100 rolls, 200 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1709 vs 0.1661 (-2.82%)
#  - End Balance: $858.89 vs $848.76 (-1.18%)
# Comparing 100 rolls, 200 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1709 vs 0.1667 (-2.43%)
#  - End Balance: $858.89 vs $850.16 (-1.02%)
# Comparing 100 rolls, 200 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1709 vs 0.1656 (-3.12%)
#  - End Balance: $858.89 vs $1276.87 (48.66%)
# Comparing 100 rolls, 200 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1709 vs 0.1667 (-2.47%)
#  - End Balance: $858.89 vs $1300.35 (51.40%)
# Comparing 100 rolls, 200 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1709 vs 0.1665 (-2.55%)
#  - End Balance: $858.89 vs $1297.36 (51.05%)
# Comparing 100 rolls, 200 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1709 vs 0.1668 (-2.39%)
#  - End Balance: $858.89 vs $5831.57 (578.97%)
# Comparing 100 rolls, 200 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1709 vs 0.1667 (-2.45%)
#  - End Balance: $858.89 vs $5810.75 (576.54%)
# Comparing 100 rolls, 200 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1709 vs 0.1666 (-2.49%)
#  - End Balance: $858.89 vs $5796.20 (574.85%)
# Comparing 100 rolls, 2000 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1661 vs 0.1630 (-1.85%)
#  - End Balance: $848.76 vs $804.23 (-5.25%)
# Comparing 100 rolls, 2000 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1661 vs 0.1652 (-0.53%)
#  - End Balance: $848.76 vs $804.69 (-5.19%)
# Comparing 100 rolls, 2000 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1661 vs 0.1688 (1.63%)
#  - End Balance: $848.76 vs $805.44 (-5.10%)
# Comparing 100 rolls, 2000 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1661 vs 0.1709 (2.91%)
#  - End Balance: $848.76 vs $858.89 (1.19%)
# Comparing 100 rolls, 2000 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1661 vs 0.1667 (0.40%)
#  - End Balance: $848.76 vs $850.16 (0.17%)
# Comparing 100 rolls, 2000 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1661 vs 0.1656 (-0.31%)
#  - End Balance: $848.76 vs $1276.87 (50.44%)
# Comparing 100 rolls, 2000 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1661 vs 0.1667 (0.37%)
#  - End Balance: $848.76 vs $1300.35 (53.21%)
# Comparing 100 rolls, 2000 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1661 vs 0.1665 (0.28%)
#  - End Balance: $848.76 vs $1297.36 (52.85%)
# Comparing 100 rolls, 2000 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1661 vs 0.1668 (0.45%)
#  - End Balance: $848.76 vs $5831.57 (587.07%)
# Comparing 100 rolls, 2000 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1661 vs 0.1667 (0.39%)
#  - End Balance: $848.76 vs $5810.75 (584.62%)
# Comparing 100 rolls, 2000 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1661 vs 0.1666 (0.35%)
#  - End Balance: $848.76 vs $5796.20 (582.90%)
# Comparing 100 rolls, 20000 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1630 (-2.24%)
#  - End Balance: $850.16 vs $804.23 (-5.40%)
# Comparing 100 rolls, 20000 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1652 (-0.92%)
#  - End Balance: $850.16 vs $804.69 (-5.35%)
# Comparing 100 rolls, 20000 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1688 (1.23%)
#  - End Balance: $850.16 vs $805.44 (-5.26%)
# Comparing 100 rolls, 20000 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1709 (2.49%)
#  - End Balance: $850.16 vs $858.89 (1.03%)
# Comparing 100 rolls, 20000 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1661 (-0.40%)
#  - End Balance: $850.16 vs $848.76 (-0.16%)
# Comparing 100 rolls, 20000 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1656 (-0.71%)
#  - End Balance: $850.16 vs $1276.87 (50.19%)
# Comparing 100 rolls, 20000 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1667 (-0.04%)
#  - End Balance: $850.16 vs $1300.35 (52.95%)
# Comparing 100 rolls, 20000 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1665 (-0.12%)
#  - End Balance: $850.16 vs $1297.36 (52.60%)
# Comparing 100 rolls, 20000 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1668 (0.04%)
#  - End Balance: $850.16 vs $5831.57 (585.94%)
# Comparing 100 rolls, 20000 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1667 (-0.01%)
#  - End Balance: $850.16 vs $5810.75 (583.49%)
# Comparing 100 rolls, 20000 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1666 (-0.06%)
#  - End Balance: $850.16 vs $5796.20 (581.78%)
# Comparing 1000 rolls, 200 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1656 vs 0.1630 (-1.55%)
#  - End Balance: $1276.87 vs $804.23 (-37.02%)
# Comparing 1000 rolls, 200 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1656 vs 0.1652 (-0.22%)
#  - End Balance: $1276.87 vs $804.69 (-36.98%)
# Comparing 1000 rolls, 200 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1656 vs 0.1688 (1.94%)
#  - End Balance: $1276.87 vs $805.44 (-36.92%)
# Comparing 1000 rolls, 200 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1656 vs 0.1709 (3.22%)
#  - End Balance: $1276.87 vs $858.89 (-32.73%)
# Comparing 1000 rolls, 200 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1656 vs 0.1661 (0.31%)
#  - End Balance: $1276.87 vs $848.76 (-33.53%)
# Comparing 1000 rolls, 200 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1656 vs 0.1667 (0.71%)
#  - End Balance: $1276.87 vs $850.16 (-33.42%)
# Comparing 1000 rolls, 200 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1656 vs 0.1667 (0.68%)
#  - End Balance: $1276.87 vs $1300.35 (1.84%)
# Comparing 1000 rolls, 200 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1656 vs 0.1665 (0.59%)
#  - End Balance: $1276.87 vs $1297.36 (1.60%)
# Comparing 1000 rolls, 200 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1656 vs 0.1668 (0.76%)
#  - End Balance: $1276.87 vs $5831.57 (356.71%)
# Comparing 1000 rolls, 200 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1656 vs 0.1667 (0.70%)
#  - End Balance: $1276.87 vs $5810.75 (355.08%)
# Comparing 1000 rolls, 200 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1656 vs 0.1666 (0.65%)
#  - End Balance: $1276.87 vs $5796.20 (353.94%)
# Comparing 1000 rolls, 2000 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1630 (-2.21%)
#  - End Balance: $1300.35 vs $804.23 (-38.15%)
# Comparing 1000 rolls, 2000 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1652 (-0.89%)
#  - End Balance: $1300.35 vs $804.69 (-38.12%)
# Comparing 1000 rolls, 2000 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1688 (1.26%)
#  - End Balance: $1300.35 vs $805.44 (-38.06%)
# Comparing 1000 rolls, 2000 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1709 (2.53%)
#  - End Balance: $1300.35 vs $858.89 (-33.95%)
# Comparing 1000 rolls, 2000 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1661 (-0.37%)
#  - End Balance: $1300.35 vs $848.76 (-34.73%)
# Comparing 1000 rolls, 2000 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1667 (0.04%)
#  - End Balance: $1300.35 vs $850.16 (-34.62%)
# Comparing 1000 rolls, 2000 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1656 (-0.67%)
#  - End Balance: $1300.35 vs $1276.87 (-1.81%)
# Comparing 1000 rolls, 2000 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1665 (-0.09%)
#  - End Balance: $1300.35 vs $1297.36 (-0.23%)
# Comparing 1000 rolls, 2000 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1668 (0.08%)
#  - End Balance: $1300.35 vs $5831.57 (348.46%)
# Comparing 1000 rolls, 2000 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1667 (0.02%)
#  - End Balance: $1300.35 vs $5810.75 (346.86%)
# Comparing 1000 rolls, 2000 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1666 (-0.02%)
#  - End Balance: $1300.35 vs $5796.20 (345.74%)
# Comparing 1000 rolls, 20000 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1665 vs 0.1630 (-2.13%)
#  - End Balance: $1297.36 vs $804.23 (-38.01%)
# Comparing 1000 rolls, 20000 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1665 vs 0.1652 (-0.81%)
#  - End Balance: $1297.36 vs $804.69 (-37.97%)
# Comparing 1000 rolls, 20000 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1665 vs 0.1688 (1.35%)
#  - End Balance: $1297.36 vs $805.44 (-37.92%)
# Comparing 1000 rolls, 20000 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1665 vs 0.1709 (2.62%)
#  - End Balance: $1297.36 vs $858.89 (-33.80%)
# Comparing 1000 rolls, 20000 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1665 vs 0.1661 (-0.28%)
#  - End Balance: $1297.36 vs $848.76 (-34.58%)
# Comparing 1000 rolls, 20000 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1665 vs 0.1667 (0.12%)
#  - End Balance: $1297.36 vs $850.16 (-34.47%)
# Comparing 1000 rolls, 20000 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1665 vs 0.1656 (-0.59%)
#  - End Balance: $1297.36 vs $1276.87 (-1.58%)
# Comparing 1000 rolls, 20000 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1665 vs 0.1667 (0.09%)
#  - End Balance: $1297.36 vs $1300.35 (0.23%)
# Comparing 1000 rolls, 20000 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1665 vs 0.1668 (0.17%)
#  - End Balance: $1297.36 vs $5831.57 (349.50%)
# Comparing 1000 rolls, 20000 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1665 vs 0.1667 (0.11%)
#  - End Balance: $1297.36 vs $5810.75 (347.89%)
# Comparing 1000 rolls, 20000 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1665 vs 0.1666 (0.06%)
#  - End Balance: $1297.36 vs $5796.20 (346.77%)
# Comparing 10000 rolls, 200 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1668 vs 0.1630 (-2.29%)
#  - End Balance: $5831.57 vs $804.23 (-86.21%)
# Comparing 10000 rolls, 200 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1668 vs 0.1652 (-0.97%)
#  - End Balance: $5831.57 vs $804.69 (-86.20%)
# Comparing 10000 rolls, 200 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1668 vs 0.1688 (1.18%)
#  - End Balance: $5831.57 vs $805.44 (-86.19%)
# Comparing 10000 rolls, 200 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1668 vs 0.1709 (2.45%)
#  - End Balance: $5831.57 vs $858.89 (-85.27%)
# Comparing 10000 rolls, 200 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1668 vs 0.1661 (-0.44%)
#  - End Balance: $5831.57 vs $848.76 (-85.45%)
# Comparing 10000 rolls, 200 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1668 vs 0.1667 (-0.04%)
#  - End Balance: $5831.57 vs $850.16 (-85.42%)
# Comparing 10000 rolls, 200 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1668 vs 0.1656 (-0.75%)
#  - End Balance: $5831.57 vs $1276.87 (-78.10%)
# Comparing 10000 rolls, 200 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1668 vs 0.1667 (-0.08%)
#  - End Balance: $5831.57 vs $1300.35 (-77.70%)
# Comparing 10000 rolls, 200 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1668 vs 0.1665 (-0.17%)
#  - End Balance: $5831.57 vs $1297.36 (-77.75%)
# Comparing 10000 rolls, 200 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1668 vs 0.1667 (-0.06%)
#  - End Balance: $5831.57 vs $5810.75 (-0.36%)
# Comparing 10000 rolls, 200 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1668 vs 0.1666 (-0.10%)
#  - End Balance: $5831.57 vs $5796.20 (-0.61%)
# Comparing 10000 rolls, 2000 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1630 (-2.23%)
#  - End Balance: $5810.75 vs $804.23 (-86.16%)
# Comparing 10000 rolls, 2000 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1652 (-0.91%)
#  - End Balance: $5810.75 vs $804.69 (-86.15%)
# Comparing 10000 rolls, 2000 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1688 (1.24%)
#  - End Balance: $5810.75 vs $805.44 (-86.14%)
# Comparing 10000 rolls, 2000 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1709 (2.51%)
#  - End Balance: $5810.75 vs $858.89 (-85.22%)
# Comparing 10000 rolls, 2000 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1661 (-0.39%)
#  - End Balance: $5810.75 vs $848.76 (-85.39%)
# Comparing 10000 rolls, 2000 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1667 (0.01%)
#  - End Balance: $5810.75 vs $850.16 (-85.37%)
# Comparing 10000 rolls, 2000 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1656 (-0.69%)
#  - End Balance: $5810.75 vs $1276.87 (-78.03%)
# Comparing 10000 rolls, 2000 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1667 vs 0.1667 (-0.02%)
#  - End Balance: $5810.75 vs $1300.35 (-77.62%)
# Comparing 10000 rolls, 2000 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1665 (-0.11%)
#  - End Balance: $5810.75 vs $1297.36 (-77.67%)
# Comparing 10000 rolls, 2000 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1667 vs 0.1668 (0.06%)
#  - End Balance: $5810.75 vs $5831.57 (0.36%)
# Comparing 10000 rolls, 2000 sims to 10000 rolls, 20000 sims:
#  - Win Rate: 0.1667 vs 0.1666 (-0.04%)
#  - End Balance: $5810.75 vs $5796.20 (-0.25%)
# Comparing 10000 rolls, 20000 sims to 10 rolls, 200 sims:
#  - Win Rate: 0.1666 vs 0.1630 (-2.19%)
#  - End Balance: $5796.20 vs $804.23 (-86.12%)
# Comparing 10000 rolls, 20000 sims to 10 rolls, 2000 sims:
#  - Win Rate: 0.1666 vs 0.1652 (-0.87%)
#  - End Balance: $5796.20 vs $804.69 (-86.12%)
# Comparing 10000 rolls, 20000 sims to 10 rolls, 20000 sims:
#  - Win Rate: 0.1666 vs 0.1688 (1.28%)
#  - End Balance: $5796.20 vs $805.44 (-86.10%)
# Comparing 10000 rolls, 20000 sims to 100 rolls, 200 sims:
#  - Win Rate: 0.1666 vs 0.1709 (2.55%)
#  - End Balance: $5796.20 vs $858.89 (-85.18%)
# Comparing 10000 rolls, 20000 sims to 100 rolls, 2000 sims:
#  - Win Rate: 0.1666 vs 0.1661 (-0.34%)
#  - End Balance: $5796.20 vs $848.76 (-85.36%)
# Comparing 10000 rolls, 20000 sims to 100 rolls, 20000 sims:
#  - Win Rate: 0.1666 vs 0.1667 (0.06%)
#  - End Balance: $5796.20 vs $850.16 (-85.33%)
# Comparing 10000 rolls, 20000 sims to 1000 rolls, 200 sims:
#  - Win Rate: 0.1666 vs 0.1656 (-0.65%)
#  - End Balance: $5796.20 vs $1276.87 (-77.97%)
# Comparing 10000 rolls, 20000 sims to 1000 rolls, 2000 sims:
#  - Win Rate: 0.1666 vs 0.1667 (0.02%)
#  - End Balance: $5796.20 vs $1300.35 (-77.57%)
# Comparing 10000 rolls, 20000 sims to 1000 rolls, 20000 sims:
#  - Win Rate: 0.1666 vs 0.1665 (-0.06%)
#  - End Balance: $5796.20 vs $1297.36 (-77.62%)
# Comparing 10000 rolls, 20000 sims to 10000 rolls, 200 sims:
#  - Win Rate: 0.1666 vs 0.1668 (0.10%)
#  - End Balance: $5796.20 vs $5831.57 (0.61%)
# Comparing 10000 rolls, 20000 sims to 10000 rolls, 2000 sims:
#  - Win Rate: 0.1666 vs 0.1667 (0.04%)
#  - End Balance: $5796.20 vs $5810.75 (0.25%)
#
# Scenarios with Highest Win Rates:
#  - 100 rolls, 200 sims: 0.1709
#  - 10 rolls, 20000 sims: 0.1688
#  - 10000 rolls, 200 sims: 0.1668

# %% [markdown]
# # Aquí hicimos varios prints de las diferencias entre distintos escenarios para poder observar mejor las pequeñas diferencias, ya que en ciertas gráficas por la escala se observaba la similitud pero todo se veìa practicamente igual.  A continuaciòn están las gráficas.

# %%
# Grafico las victorias
plt.figure(figsize=(12, 6))
plt.bar(range(len(simulation_results)), [result["average_win_rate"] for result in simulation_results], align='center', alpha=0.5)
plt.xticks(range(len(simulation_results)), [f"{result['num_rolls_per_game']} rolls, {result['num_sims']} sims" for result in simulation_results], rotation=45, ha='right')
plt.xlabel('Simulation Scenarios')
plt.ylabel('Average Win Rate')
plt.title('Average Win Rates for Different Simulation Scenarios')
plt.tight_layout()
plt.show()

# Grafico balances finales
plt.figure(figsize=(12, 6))
plt.bar(range(len(simulation_results)), [result["average_end_balance"] for result in simulation_results], align='center', alpha=0.5)
plt.xticks(range(len(simulation_results)), [f"{result['num_rolls_per_game']} rolls, {result['num_sims']} sims" for result in simulation_results], rotation=45, ha='right')
plt.xlabel('Simulation Scenarios')
plt.ylabel('Average End Balance')
plt.title('Average End Balances for Different Simulation Scenarios')
plt.tight_layout()
plt.show()

# Comparo victorias
plt.figure(figsize=(8, 8))
plt.pie(win_rates_data, labels=[f"{result['num_rolls_per_game']} rolls, {result['num_sims']} sims" for result in simulation_results], autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of Average Win Rates Across Simulation Scenarios')
plt.show()
